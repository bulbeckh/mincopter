# %% [markdown]
# # Derivation of Complementary Filter (for state estimation)
# ### Magnetometer
# If we define $R$ as a rotation matrix from inertial (NED) to body, then we have $$M_B = R^{T}M_G$$ We know that the global magnetic field $M_G$ will be $$M_G=R_\text{offset}
# \begin{bmatrix}
# 1 \\
# 0 \\
# 0
# \end{bmatrix}
# $$
# Assuming the euler angles are **extrinsic** in $R$, we define the order of rotation as $$R=R_{\psi}R_{\theta}R_{\phi}$$ with $$\text{Roll}=\phi, \text{Pitch}=\theta, \text{Yaw}=\psi$$
# Finally $$R^{T} = R_{\phi}^{T}R_{\theta}^{T}R_{\psi}^{T}$$
#
# $$R^{T}=\begin{bmatrix}
# \cos{\theta}\cos{\psi} & \cos{\theta}\sin{\psi} & -\sin{\theta} \\
# \sin{\phi}\sin{\theta}\cos{\psi}-\cos{\phi}\sin{\psi} & \sin{\phi}\sin{\theta}\sin{\psi}+\cos{\phi}\cos{\psi} & \sin{\phi}\cos{\theta} \\
# \cos{\phi}\sin{\theta}\cos{\psi}+\sin{\phi}\sin{\psi} & \cos{\phi}\sin{\theta}\sin{\psi}-\sin{\phi}\cos{\psi} & \cos{\phi}\cos{\theta}
# \end{bmatrix}$$
#
# For now, we assume that $R_\text{offset}=\mathbf{I}_{3x3}$
#
# ### Accelerometer
# Similarly, $$A_B = R^{T}A_G$$ with the gravity vector pointing upward in the NED frame $$A_G=\begin{bmatrix} 0 \\ 0 \\ -g \end{bmatrix}$$ This gives us $$\begin{bmatrix} a_x \\ a_y \\ a_z \end{bmatrix} = \begin{bmatrix} g\sin{\theta} \\ -g\sin{\phi}\cos{\theta} \\ -g\cos{\phi}\cos{\theta} \end{bmatrix}$$
#
# For pitch
# $$\begin{align}
# a_y^{2}+a_z^{2} &= g^{2}\sin^{2}{\phi}\cos^{2}{\theta} + g^{2}\cos^{2}{\phi}\cos^{2}{\theta} \\
# &= g^{2}\cos^{2}{\theta}(\sin^{2}{\phi}+\cos^{2}{\phi}) \\
# &= g^{2}\cos^{2}{\theta} \\
# \sqrt{a_y^{2}+a_z^{2}} &= g\cos{\theta} \\
# \tan{\theta} &= \frac{g\sin{\theta}}{g\cos{\theta}} \\
# &= \frac{a_x}{\sqrt{a_y^{2}+a_z^{2}}}
# \end{align}$$
# $$\theta,\text{(pitch)} = \text{atan2}(a_x,\sqrt{a_y^{2}+a_z^{2}})\text{  valid between  }-\frac{\pi}{2}\leq\theta\leq\frac{\pi}{2}$$
#
# For roll $$\begin{align}
# \frac{a_y}{a_z} &= \frac{-g\sin{\phi}\cos{\theta}}{-g\cos{\phi}\cos{\theta}} \\
# &= \tan{\phi}
# \end{align}$$
# $$\phi,\text{(roll)} = \text{atan2}(a_y,a_z)$$
# However, due to our NED frame and the definition of atan2 (which checks the sign of the second argument to determine if we are above/below +-$\frac{\pi}{2}$), we need to negate both arguments, giving us:
# $$\phi,\text{(roll)} = \text{atan2}(-a_y,-a_z)\text{  valid between  }-\pi\leq\phi\leq\pi$$
#
# ### Gyrometer
# We integrate the gyrometer to obtain an estimate of the orientation. This is what is then fused with the orientation estimate from the accelerometer and magnetometer.
#
# $$\theta_{\omega}=\begin{bmatrix}\theta_{x_{t-1}}+\Delta_{t}\omega_{x}\\ \theta_{y_{t-1}}+\Delta_{t}\omega_{y} \\ \theta_{z_{t-1}}+\Delta_{t}\omega_{z}
# \end{bmatrix}$$
#
# ### Fusion
# We simply use a weighted average of the two estimates with a parameter $\alpha$.
#
# $$\mathbf{\theta}=\alpha\theta_{\omega} + (1-\alpha)\theta_{\text{mag,acc}}$$
#
# ### Filtering
# Our accelerometer and gyrometer signals are noisy so we need to filter before fusing them. We read both at 1kHz but fuse and integrate at 100Hz.

# %%
import casadi as ca
import numpy as np
import math

roll = ca.SX.sym('roll')
pitch = ca.SX.sym('pitch')
yaw = ca.SX.sym('yaw')

r_roll = ca.SX_eye(3)
r_roll[1:,1:] = np.array([[ca.cos(roll), -ca.sin(roll)],
                 [ca.sin(roll), ca.cos(roll)]])
r_pitch = ca.SX_eye(3)
r_pitch[[0,2],[0,2]] = np.array([[ca.cos(pitch), ca.sin(pitch)],
                 [-ca.sin(pitch), ca.cos(pitch)]])
r_yaw = ca.SX_eye(3)
r_yaw[:2,:2] = np.array([[ca.cos(yaw), -ca.sin(yaw)],
                 [ca.sin(yaw), ca.cos(yaw)]])

print("ROLL", r_roll)
print("PITCH", r_pitch)
print("YAW", r_yaw)
r = r_pitch @ r_roll
print("R (pitch, roll)")
for i in range(0,3):
    for j in range(0,3):
        print(r[i, j],end=',')
    print()

r_t = (r_roll.T @ r_pitch.T @ r_yaw.T)
print("R.T")
for i in range(0,3):
    for j in range(0,3):
        print(r_t[i, j],end=',')
    print()

## Compute R_Offset
rot_y = np.array([
        [math.cos(68*math.pi/180), 0, math.sin(68*math.pi/180)],
        [0, 1, 0],
        [-math.sin(68*math.pi/180), 0, math.cos(68*math.pi/180)]], dtype=np.float64)

## Rotation about z-axis
rot_z = np.array([
            [math.cos(11*math.pi/180), -math.sin(11*math.pi/180), 0],
            [math.sin(11*math.pi/180), math.cos(11*math.pi/180), 0],
            [0, 0, 1]], dtype=np.float64)

## We rotate extrinsically here (w reference to a changing frame) - pitch, then yaw
print(rot_z @ rot_y)
# Out:
# ROLL
# [[1, 00, 00],
#  [00, cos(roll), (-sin(roll))],
#  [00, sin(roll), cos(roll)]]
# PITCH
# [[cos(pitch), 00, sin(pitch)],
#  [00, 1, 00],
#  [(-sin(pitch)), 00, cos(pitch)]]
# YAW
# [[cos(yaw), (-sin(yaw)), 00],
#  [sin(yaw), cos(yaw), 00],
#  [00, 00, 1]]
# R (pitch, roll)
# cos(pitch),(sin(pitch)*sin(roll)),(sin(pitch)*cos(roll)),
# 00,cos(roll),(-sin(roll)),
# (-sin(pitch)),(cos(pitch)*sin(roll)),(cos(pitch)*cos(roll)),
# R.T
# (cos(pitch)*cos(yaw)),(cos(pitch)*sin(yaw)),(-sin(pitch)),
# (((sin(roll)*sin(pitch))*cos(yaw))-(cos(roll)*sin(yaw))),(((sin(roll)*sin(pitch))*sin(yaw))+(cos(roll)*cos(yaw))),(sin(roll)*cos(pitch)),
# (((cos(roll)*sin(pitch))*cos(yaw))+(sin(roll)*sin(yaw))),(((cos(roll)*sin(pitch))*sin(yaw))-(sin(roll)*cos(yaw))),(cos(roll)*cos(pitch)),
# [[ 0.36772402 -0.190809    0.91014888]
#  [ 0.07147831  0.98162718  0.17691502]
#  [-0.92718385  0.          0.37460659]]

# %%
''' This block reads a log file created by the gazebo plugin which logs the x,y,z accelerometer and gyrometer readings
at 1kHz. We can then use this to re-construct the complementary filter and compare it with the gz estimated position.
'''
from matplotlib import pyplot as plt

x = {'ax': [],
     'ay': [],
     'az': [],
     'gx': [],
     'gy': [],
     'gz': [],
     'mx': [],
     'my': [],
     'mz': []
    }

y = {'ax': [],
     'ay': [],
     'az': [],
     'gx': [],
     'gy': [],
     'gz': [],
     'mx': [],
     'my': [],
     'mz': []
    }

y_av = {'ax': [],
     'ay': [],
     'az': [],
     'gx': [],
     'gy': [],
     'gz': [],
     'mx': [],
     'my': [],
     'mz': []
    }

y_lp = {'ax': [],
     'ay': [],
     'az': [],
     'gx': [],
     'gy': [],
     'gz': [],
     'mx': [],
     'my': [],
     'mz': []
    }

## TODO Replace this with the parser class instance
with open('/tmp/gz_imu_logfile.txt','r') as rfile:
    lines = rfile.readlines()

for i,e in enumerate(lines):
    line = e.split(',')

    try:
        x_next = int(line[0])
        y_next = float(line[2])
    except:
        continue

    x[line[1]].append(x_next)
    y[line[1]].append(y_next)

    if len(x[line[1]])<=1:
        ## First reading for this item 
        y_lp[line[1]].append(y_next)
        y_av[line[1]].append(y_next)
    else:
        ## Low Pass Filter
        a = 0.5
        y_lp[line[1]].append(a*y_next + (1-a)*y_lp[line[1]][-1])

        ## Average Filter
        y_av[line[1]].append(sum(y[line[1]][-10:])/10)

# %%
fig, ax = plt.subplots(2,1, figsize=(20,8))

rmin=2000
rmax=10000 ## 10 sec
target = 'ax'

ax[0].plot(x[target][rmin:rmax],y[target][rmin:rmax], label='raw')
ax[0].plot(x[target][rmin:rmax:10], y[target][rmin:rmax:10], color='red', label='10th')
ax[0].plot(x[target][rmin:rmax], y_lp[target][rmin:rmax], color='green', alpha=0.5, label='filtered 1st ord')
ax[0].plot(x[target][rmin:rmax], y_av[target][rmin:rmax], color='black', alpha=0.5, label='avg')
ax[0].plot(x[target][rmin:rmax:10], y_av[target][rmin:rmax:10], color='yellow', alpha=0.5, label='avg - 10th')
#ax.set_ylim(-2.5,2.5)
ax[0].set_title(target)
ax[0].legend()


pitch_acc = [math.atan2(y['ax'][i], math.sqrt(y['ay'][i]**2 + y['az'][i]**2)) for i in range(0,len(y['ax']))]

ax[1].plot(x['ax'][rmin:rmax], pitch_acc[rmin:rmax])

roll_acc = math.atan2(-y['ay'][i], -y['az'][i])

fig.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 21
#      17 pitch_acc = [math.atan2(y['ax'][i], math.sqrt(y['ay'][i]**2 + y['az'][i]**2)) for i in range(0,len(y['ax']))]
#      19 ax[1].plot(x['ax'][rmin:rmax], pitch_acc[rmin:rmax])
# ---> 21 roll_acc = math.atan2(-y['ay'][i], -y['az'][i])
#      23 fig.show()
#
# IndexError: list index out of range

# %%
fig, ax = plt.subplots(1,1, figsize=(20,6))

rmin=0
rmax=10000 ## 10 sec
target = 'gx'

ax.plot(x[target][rmin:rmax],y[target][rmin:rmax], label='raw')
ax.plot(x[target][rmin:rmax:10], y[target][rmin:rmax:10], color='red', label='10th')
ax.plot(x[target][rmin:rmax], y_lp[target][rmin:rmax], color='green', alpha=0.5, label='filtered 1st ord')
ax.plot(x[target][rmin:rmax], y_av[target][rmin:rmax], color='black', alpha=0.5, label='avg')
ax.plot(x[target][rmin:rmax:10], y_av[target][rmin:rmax:10], color='yellow', alpha=0.5, label='avg - 10th')
#ax.set_ylim(-2.5,2.5)
ax.set_title(target)
ax.legend()
fig.show()

# %% [markdown]
# ### Hampel Filter
# Used to reject large gyro and accelerometer spikes to takeoff or collisions.
#
# $$\textbf{MAD}=\text{median}(\lvert\mathbf{X}_{i}-\mathbf{\bar{X}}\rvert)$$
# $$\mathbf{\bar{X}}=\text{median}(X_w)$$
#
# $$\text{Reject if:} \lvert X_{i}-\mathbf{\bar{x}} \rvert > \textbf{k}\times\text{MAD}\times1.4826$$

# %%
import statistics

y_post = []

rmax=100

bound=20
k=1

upper = []
lower = []

for i in range(0,rmax):
    if i==0:
        med=y['ax'][i]
    else:
        med = statistics.median(y['ax'][max(0,i-bound):i])

    if i==0:
        y_post.append(y['ax'][i])
        upper.append(med)
        lower.append(med)
        
    else:
        mad = statistics.median([abs(e-med) for e in y['ax'][max(0,i-bound):i]])

        upper.append(med+k*mad*1.4826)
        lower.append(med-k*mad*1.4826)
        
        if abs(y['ax'][i] - med) > k*mad*1.4826:
            y_post.append(med)
        else:
            y_post.append(y['ax'][i])

fig, ax = plt.subplots(1,1, figsize=(15,6))
ax.plot(x['ax'][0:rmax], y['ax'][0:rmax], label='raw')
ax.plot(x['ax'][0:rmax], y_post, label='filtered')
ax.plot(x['ax'][0:rmax], upper, linestyle='--', color='purple', label='hampel bounds')
ax.plot(x['ax'][0:rmax], lower, linestyle='--', color='purple')
ax.legend()
#plt.ylim(-10,10)
plt.show()

# %% [markdown]
# ### Recreation of state estimation using complementary filter

# %%
import os
from parse import Parser
print(os.getcwd())
p = Parser()

mc_x, mc_y = p.read_mincopter_log('../../build-generic/mincopter_log.txt')

for j in mc_y.keys():
    print(f"Found logfile entry {j:13} with y[0:{len(mc_y[j])}] and x[0:{len(mc_x[j])}]")
# Out:
# /home/henry/Documents/mc-working-dir/mc-dev/state/design
# Found logfile entry roll          with y[0:4273] and x[0:4273]
# Found logfile entry pitch         with y[0:4273] and x[0:4273]
# Found logfile entry yaw           with y[0:4273] and x[0:4273]
# Found logfile entry er_x          with y[0:4273] and x[0:4273]
# Found logfile entry er_y          with y[0:4273] and x[0:4273]
# Found logfile entry er_z          with y[0:4273] and x[0:4273]
# Found logfile entry pos_x         with y[0:4273] and x[0:4273]
# Found logfile entry pos_y         with y[0:4273] and x[0:4273]
# Found logfile entry pos_z         with y[0:4273] and x[0:4273]
# Found logfile entry vel_x         with y[0:4273] and x[0:4273]
# Found logfile entry vel_y         with y[0:4273] and x[0:4273]
# Found logfile entry vel_z         with y[0:4273] and x[0:4273]
# Found logfile entry force         with y[0:4273] and x[0:4273]
# Found logfile entry rt            with y[0:4273] and x[0:4273]
# ...

# %%
import math

att_acc = {'roll': [], 'pitch': []}
att_gyr = {'roll': [], 'pitch': [], 'yaw': []}

att = {'roll': [], 'pitch': [], 'yaw': []}
    
anorms = []

## Get the largest ranges that is present in all readings
rmax = min([len(y[k]) for k in y.keys()])
print(rmax, 'readings')

''' Accelerometer readings available in y['ax'] and y_av['ax']
Gyro readings in y['gx'] and y_av['gx'] for the filtered version
'''

## Temporary roll,pitch,yaw
troll=0
tpitch=0
tyaw=0

## We keep track of a parameter that contains the norm of the linear acceleration vector
anorm_estimates = []
anorm_estimate = 0
dvel_x = 0
dvel_y = 0
dvel_z = 0

for i in range(0,rmax,10):
    ## Retrieve every 10th reading (100Hz)

    ## 1. Calculate roll/pitch from accelerometer readings
    pitch_acc = math.atan2(y_av['ax'][i], math.sqrt(y_av['ay'][i]**2 + y_av['az'][i]**2))
    roll_acc = math.atan2(-y_av['ay'][i], -y_av['az'][i])

    att_acc['roll'].append(roll_acc)
    att_acc['pitch'].append(pitch_acc)

    ## 2. Integrate gyro to get roll/pitch prediction
    roll_gyr = troll + 0.01*y['gx'][i]
    pitch_gyr = tpitch + 0.01*y['gy'][i]
    yaw_gyr = tyaw + 0.01*y['gz'][i]
    
    att_gyr['roll'].append(roll_gyr)
    att_gyr['pitch'].append(pitch_gyr)
    att_gyr['yaw'].append(yaw_gyr)

    ## 3a. Use magnetometer to estimate yaw
    m_norm = math.sqrt(y['mx'][i]**2 + y['my'][i]**2 + y['mz'][i]**2)
    mx_est = y['mx'][i] / m_norm
    my_est = y['my'][i] / m_norm
    mz_est = y['mz'][i] / m_norm    
    yaw_mag = math.atan2(-1*my_est*math.cos(troll) + mz_est*math.sin(troll),
                         mx_est*math.cos(tpitch) + my_est*math.sin(tpitch)*math.sin(troll) + mz_est*math.sin(tpitch)*math.cos(troll))

    ## 3b. Add compass offset
    yaw_mag += 0.19
    
    ## Fuse with a weight based on how much we are accelerating
    a_norm = math.sqrt(y_av['ax'][i]**2 + y_av['ay'][i]**2 + y_av['az'][i]**2)
    anorms.append(a_norm)

    dvel_x = (mc_y['vel_x'][i//10] - (mc_y['vel_x'][i//10 - 1] if i!=0 else 0))/0.01
    dvel_y = (mc_y['vel_y'][i//10] - (mc_y['vel_y'][i//10 - 1] if i!=0 else 0))/0.01
    dvel_z = (mc_y['vel_z'][i//10] - (mc_y['vel_z'][i//10 - 1] if i!=0 else 0))/0.01
              
    anorm_estimate = math.sqrt(dvel_x**2 + dvel_y**2 + dvel_z**2)
    anorm_estimates.append(anorm_estimate)
    
    div = abs(a_norm-9.8)
    #div = abs(anorm_estimate)
    if div>0.5:
        ## Ignore accel reading altogether
        a = 1
    else:
        ## Accel reading should by up to 2% of the fused value when we are stationary
        a = 1 - (0.5-div)*0.05/0.5
        #a=0

    a=0.998
    a_yaw=0.8
    att['roll'].append(a*roll_gyr + (1-a)*roll_acc)
    att['pitch'].append(a*pitch_gyr + (1-a)*pitch_acc)
    att['yaw'].append(a_yaw*yaw_gyr + (1-a_yaw)*yaw_mag)

    troll = att['roll'][-1]
    tpitch = att['pitch'][-1]
    tyaw = att['yaw'][-1]

fig, ax = plt.subplots(10,1, figsize=(20,32))
xlen = min(len(x['ax'][::10]), len(att['roll']))

ax[0].plot(x['ax'][::10][:xlen], att['roll'][:xlen], label='filtered', linestyle='--')
ax[0].plot(x['ax'][::10][:xlen], att_acc['roll'][:xlen], label='acc-corrected', alpha=0.5)
ax[0].plot(x['ax'][::10][:xlen], att_gyr['roll'][:xlen], label='gyr', alpha=0.5)
ax[0].plot(mc_x['roll'], mc_y['roll'], label='actual')
ax[0].set_ylim(-0.9,0.9)
ax[0].axhline(y=math.pi/4, color='purple', linestyle='--')
ax[0].axhline(y=-math.pi/4, color='purple', linestyle='--')
ax[0].set_title(r'Roll $\phi$')
ax[0].legend()

ax[1].plot(x['ax'][::10][:xlen], att['pitch'][:xlen], label='filtered', linestyle='--')
ax[1].plot(x['ax'][::10][:xlen], att_acc['pitch'][:xlen], label='acc-corrected', alpha=0.5)
ax[1].plot(x['ax'][::10][:xlen], att_gyr['pitch'][:xlen], label='gyr', alpha=0.5)
ax[1].plot(mc_x['roll'], mc_y['pitch'], label='actual')
ax[1].set_ylim(-0.9, 0.9)
ax[1].axhline(y=math.pi/4, color='purple', linestyle='--')
ax[1].axhline(y=-math.pi/4, color='purple', linestyle='--')
ax[1].set_title(r'Pitch $\theta$')
ax[1].legend()

ax[2].plot(anorms)
ax[2].axhline(y=9.8, color='red', linestyle='--', alpha=0.7)
ax[2].axhline(y=9.8+1, color='purple', linestyle='--', alpha=0.7)
ax[2].axhline(y=9.8-1, color='purple', linestyle='--', alpha=0.7)
ax[2].set_ylim(5,15)
ax[2].set_title('Norm of the accelerometer measurement')

ax[3].plot(x['ax'], y['ax'])
ax[3].plot(x['ax'], y_av['ax'])
ax[3].set_ylim(-1,1)

ax[4].plot(x['ax'], y['ay'])
ax[4].plot(x['ay'], y_av['ay'])
ax[4].set_ylim(-1,1)

ax[5].plot(x['az'], y['az'])
ax[5].plot(x['az'], y_av['az'])
ax[5].set_ylim(-15,-8)

ax[6].plot(mc_x['vel_x'], mc_y['vel_x'], label='velx')
ax[6].plot(mc_x['vel_y'], mc_y['vel_y'], label='vely')
ax[6].plot(mc_x['vel_z'], mc_y['vel_z'], label='velz')
ax[6].legend()
ax[6].set_title('Velocity')

ax[7].plot(mc_x['vel_x'][:len(anorm_estimates)], anorm_estimates)
ax[7].axhline(y=1, color='red', linestyle='--')
ax[7].axhline(y=2, color='red', linestyle='--')
ax[7].axhline(y=3, color='red', linestyle='--')

ax[8].plot(x['ax'][::10][:xlen], att['yaw'][:xlen], label='yaw est', linestyle='--')
ax[8].plot(mc_x['yaw'], mc_y['yaw'], label='actual')
ax[8].set_title(r'Yaw $\psi$')
ax[8].legend()

ax[9].plot(x['gz'][::10][:xlen], y['gz'][::10][:xlen])
    
plt.show()
# Out:
# 38784 readings

# %% [markdown]
# ### Finding when to fuse the accelerometer reading
# Finding what divergence from the gravitational vector we gives us lowest mean square error

# %%
math.atan2(-0.2, -9.8)*180/math.pi + 180

# %%
math.atan(2/9.8)*180/math.pi
